# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
plt.set_cmap('Pastel1')
import seaborn as sns
import random


N = 240
V = 441
x1 = 21
x2 = 21
nsrcs = 6

# %% [markdown]
# ## Question 1.1

# %%
# Question 1.1

AV = np.array([0,20,0,0,0,0])
IV = np.array([30,45,60,40,40,40])
ONES = np.array([15,20,25,15,20,25])

# %%
TC = np.zeros((nsrcs,N))

for x in range(nsrcs):
    i = 0
    while i < N and i+ONES[x] < N:
        if i == 0:
            i += AV[x]

        TC[x][i:i+ONES[x]] = 1
        i += IV[x]

# %%
for x in range(nsrcs):
    print(np.mean(TC[x]))
    TC[x] = (TC[x] - np.mean(TC[x])) / np.std(TC[x])
# Out:
# 0.5
# 0.4166666666666667
# 0.4166666666666667
# 0.375
# 0.5
# 0.625

# %%
plt.plot(TC[0])
plt.plot(TC[1])
# plt.plot(TC[2])

# %% [markdown]
# ## Question 1.2

# %%
sns.heatmap(np.corrcoef(TC))
plt.show()

# %%
print(np.corrcoef(TC)[3][4])
print(np.corrcoef(TC)[4][5])
# Out:
# 0.7745966692414841
# 0.774596669241484

# %%
np.corrcoef(TC)
# Out:
# array([[ 1.00000000e+00, -6.47630098e-18,  1.69030851e-01,
#          8.60662966e-02,  0.00000000e+00,  8.60662966e-02],
#        [-6.47630098e-18,  1.00000000e+00, -2.85714286e-02,
#          1.30930734e-01,  1.57281595e-17, -1.30930734e-01],
#        [ 1.69030851e-01, -2.85714286e-02,  1.00000000e+00,
#          4.36435780e-02, -1.20274161e-17,  1.30930734e-01],
#        [ 8.60662966e-02,  1.30930734e-01,  4.36435780e-02,
#          1.00000000e+00,  7.74596669e-01,  6.00000000e-01],
#        [ 0.00000000e+00,  1.57281595e-17, -1.20274161e-17,
#          7.74596669e-01,  1.00000000e+00,  7.74596669e-01],
#        [ 8.60662966e-02, -1.30930734e-01,  1.30930734e-01,
#          6.00000000e-01,  7.74596669e-01,  1.00000000e+00]])

# %% [markdown]
# ## Question 1.3

# %%
def construct_tmpSM(vx, vy, hx, hy):
    tmpsm = np.zeros((x1,x2))
    for i in range(len(tmpsm[vx:vy+1])):
        tmpsm[vx:vy+1][i][hx:hy+1] = 1
    return tmpsm

# %%
tmpSM = []

tmpSM.append(construct_tmpSM(2,6,2,6))
tmpSM.append(construct_tmpSM(2,6,15,19))
tmpSM.append(construct_tmpSM(8,13,2,6))
tmpSM.append(construct_tmpSM(8,13,15,19))
tmpSM.append(construct_tmpSM(15,19,2,6))
tmpSM.append(construct_tmpSM(15,19,15,19))

# %%
def plotSM(data):
    fig, ax = plt.subplots()
    sns.heatmap(data, ax=ax)
    ax.set_xlim(1,21)
    ax.set_ylim(21,1)
    plt.show()

# %%
plotSM(tmpSM[0])
plotSM(tmpSM[1])

# %%
SM = np.reshape(tmpSM, (6, 441))

# %%
sns.heatmap(np.corrcoef(SM))
plt.show()

# %% [markdown]
# ## Question 1.4

# %%
Gt = np.random.normal(loc=0.0, scale=np.sqrt(0.25), size=(240,6))
Gs = np.random.normal(loc=0.0, scale=np.sqrt(0.015), size=(6,441))

# random.seed(0)

# Gt = []
# Gs = []
# for i in range(nsrcs):
#     Gt.append(np.random.randn(240) * np.sqrt(0.25))
#     Gs.append(np.random.randn(441) * np.sqrt(0.015))
    
# Gt = np.transpose(Gt)
# Gt = np.random.normal(loc=0.0, scale=0.25, size=(240,6))
# Ga = np.random.normal(loc=0.0, scale=0.015, size=(6,441))

# %%
len(Gt)
# Out:
# 240

# %%
sns.heatmap(np.corrcoef(np.transpose(Gt)))
plt.show()
sns.heatmap(np.corrcoef(Gs))
plt.show()

# %%
# sns.displot(Ga, legend=False)
# plt.show()
# sns.displot(Gt, legend=False)
# plt.show()

sns.distplot(Gt)
plt.show()
sns.distplot(Gs)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
wuh = np.reshape(np.matmul(Gt,Gs),(240,441))

# %% [markdown]
# ## Question 1.5

# %%
X = np.matmul(np.transpose(TC) + Gt, SM + Gs)

# %%
X.shape
# Out:
# (240, 441)

# %%
import random

random.seed(1)

a = random.sample(range(V), 100)

for i in a:
    sns.lineplot(data = np.transpose(np.transpose(X)[i]), dashes=False, palette = 'rainbow', alpha=0.4)
plt.tight_layout()
# plt.legend(a)
plt.show()

# %%
varX = []
for i in range(len(np.transpose(X))):
    varX.append(np.var(np.transpose(X)[i]))

# %%
plt.plot(varX)
plt.show()

# %%
# # Standardise
# for i in range(len(X)):
#     X[i] = (X[i] - np.mean(X[i])) / np.std(X[i])

# %%
# Standardise
X = np.transpose(X)
for j in range(441):
    X[j] = (X[j] - np.mean(X[j])) / np.std(X[j])
X = np.transpose(X)

# %%
X
# Out:
# array([[ 2.24461234e-01,  3.94504421e-01, -1.53611225e+00, ...,
#         -1.40072531e-01, -8.35055643e-02, -7.91492389e-01],
#        [ 3.62652620e-01, -3.73809877e-01, -1.15660309e+00, ...,
#         -4.85734003e-02,  1.14955756e+00, -1.30151884e+00],
#        [ 4.14825008e-01, -4.65766840e-04, -9.85660286e-01, ...,
#          2.16697979e-02, -2.92917300e-01, -7.70902563e-01],
#        ...,
#        [-8.25806355e-01,  1.39987036e+00,  7.23340943e-01, ...,
#         -7.33343119e-02, -5.61685645e-01,  1.08513369e+00],
#        [-1.16886509e+00,  1.14113070e+00,  9.06766157e-01, ...,
#         -2.16473995e-01,  2.00876906e-01,  1.07639728e+00],
#        [-2.08486427e+00,  2.62949597e+00, -5.49709970e-01, ...,
#         -3.96817753e-01,  2.15467818e-02,  8.07446625e-01]])

# %% [markdown]
# ## Question 2.1

# %%
D = np.transpose(TC)
Dt = np.transpose(D)

A_lsr = np.matmul(np.matmul(np.linalg.inv(np.matmul(Dt, D)), Dt), X)
D_lsr = np.matmul(X,np.transpose(A_lsr))

# %%
np.mean(A_lsr)
# Out:
# 0.051412080679766846

# %%
len(A_lsr[0])
# Out:
# 441

# %%
sns.heatmap(np.reshape(A_lsr[0], (21, 21)))
plt.show()

# %%
plt.plot(np.transpose(D_lsr)[0])
plt.show()

# %%
plt.scatter(np.transpose(D_lsr)[2], np.transpose(X)[29])
plt.scatter(np.transpose(D_lsr)[2], np.transpose(X)[29])
plt.show()

# %%
X.shape
# Out:
# (240, 441)

# %% [markdown]
# ## Question 2.2

# %%
lmbda = 0.5
I = np.identity(6)
A_rr = np.linalg.inv((Dt @ D) + lmbda*I) @ Dt @ X
D_rr = X @ np.transpose(A_rr)

# %%
c_tlsr = []
c_trr = []

for i in range(6):
    c_tlsr.append(max(np.corrcoef(np.transpose(D_lsr), TC[i])[-1, :-1]))
    c_trr.append(max(np.corrcoef(np.transpose(D_rr), TC[i])[-1, :-1]))

# %%
print(sum(c_tlsr))
print(sum(c_trr))
# Out:
# 5.2802652621349475
# 5.284858537943125

# %%
lmbda = 1000
A_rr = np.linalg.inv((Dt @ D) + lmbda * I) @ Dt @ X
D_rr = X @ np.transpose(A_rr)

# %%
plt.plot(A_rr[0])
plt.show()

# %%
plt.plot(A_lsr[0])
plt.show()

# %% [markdown]
# ## Question 2.3

# %%
random.seed(2)

for i in range(10):
    Gt = np.random.normal(loc=0.0, scale=np.sqrt(0.25), size=(240,6))
    Gs = np.random.normal(loc=0.0, scale=np.sqrt(0.015), size=(6,441))
    X = np.matmul(np.transpose(TC) + Gt, SM + Gs)
    # Standardise
    X = np.transpose(X)
    for j in range(len(X)):
        X[j] = (X[j] - np.mean(X[j])) / np.std(X[j])
    X = np.transpose(X)

# %%
def compute_MSE_sum(rho, X):
    step = 1/(np.linalg.norm(D @ Dt)*1.1)
    thr = rho*N*step
    Ao = np.zeros((nsrcs, 1))
    A = np.zeros((nsrcs, 1))
    A_lr = np.zeros((x1*x2, nsrcs))

    for k in range(0,x1*x2):
        tmp = step * (Dt @ (np.reshape(np.transpose(X)[k],(240,1)) - (D @ Ao)))
        A = Ao + tmp
        A = (1/(1+thr)) * np.sign(A)* np.maximum(np.zeros((nsrcs, 1)), abs(A)-thr) 
        for i in range(10):
            Ao = A
            A = Ao + step*(Dt @ (np.reshape(np.transpose(X)[k],(240,1)) - (D @ Ao)))
            A = (1/(1+thr)) * np.sign(A)*np.maximum(np.zeros((nsrcs, 1)), abs(A)-thr)
        A_lr[k] =  np.reshape(A, (6))

    A_lr = np.transpose(A_lr)
    D_lr = X @ np.transpose(A_lr)
    
#     return np.linalg.norm(X-(D_lr @ A_lr),ord=2)**2 /(N*V)

# #     s = 0
# #     for v in range(V):
# #         s += (np.linalg.norm(np.reshape(np.transpose(X)[v], (240,1)) - (D_lr @ np.reshape(np.transpose(A_lr)[v], (6,1))), ord=2)**2)/(N*V)
# #     MSE_sum = s
# #     return MSE_sum
        
    return sum(sum((X-(D_lr @ A_lr)))**2)/(N*V)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-386fbe9feeda> in <module>
# ----> 1 sum(sum((X-(D_lr @ A_lr)))**2)/(N*V)
#
# NameError: name 'D_lr' is not defined

# %%
random.seed(2)

rho_MSE = []
for rho in list(np.arange(0.0,1.05,0.05)):
    MSE = []
    for i in range(10):
        Gt = np.random.normal(loc=0.0, scale=np.sqrt(0.25), size=(240,6))
        Gs = np.random.normal(loc=0.0, scale=np.sqrt(0.015), size=(6,441))
        X = np.matmul(np.transpose(TC) + Gt, SM + Gs)
        
        # Standardise
        X = np.transpose(X)
        for j in range(len(X)):
            X[j] = (X[j] - np.mean(X[j])) / np.std(X[j])
        X = np.transpose(X)
        
        MSE.append(compute_MSE_sum(rho, X))
    rho_MSE.append([rho,np.mean(MSE)])

# %%
plt.plot(np.transpose(rho_MSE)[0], np.transpose(rho_MSE)[1])
plt.scatter(x=np.transpose(rho_MSE)[0], y=np.transpose(rho_MSE)[1])
plt.show()

# %%
X.shape
# Out:
# (240, 441)

# %% [markdown]
# ## Question 2.4

# %%
def compute_Alr(rho, X):
    step = 1/(np.linalg.norm(D @ Dt)*1.1)
    thr = rho*N*step
    Ao = np.zeros((nsrcs, 1))
    A = np.zeros((nsrcs, 1))
    A_lr = np.zeros((x1*x2, nsrcs))

    for k in range(0,x1*x2):
        tmp = step * (Dt @ (np.reshape(np.transpose(X)[k],(240,1)) - (D @ Ao)))
        A = Ao + tmp
        A = (1/(1+thr)) * np.sign(A)* np.maximum(np.zeros((nsrcs, 1)), abs(A)-thr) 
        for i in range(10):
            Ao = A
            A = Ao + step*(Dt @ (np.reshape(np.transpose(X)[k],(240,1)) - (D @ Ao)))
            A = (1/(1+thr)) * np.sign(A)*np.maximum(np.zeros((nsrcs, 1)), abs(A)-thr)
        A_lr[k] =  np.reshape(A, (6))

    A_lr = np.transpose(A_lr)
    return A_lr

# %%
rho = 0.5
A_lr = compute_Alr(rho, X)
D_lr = X @ np.transpose(A_lr)

c_trr = []
c_srr = []
c_tlr = []
c_slr = []

for i in range(6):
    c_trr.append(max(np.corrcoef(np.transpose(D_rr), TC[i])[-1, :-1]))
    c_srr.append(max(np.corrcoef(A_rr, SM[i])[-1, :-1]))
    c_tlr.append(max(np.corrcoef(np.transpose(D_lr), TC[i])[-1, :-1]))
    c_slr.append(max(np.corrcoef(A_lr, SM[i])[-1, :-1]))

# %%
print(sum(c_tlr))
print(sum(c_trr))
print()
print(sum(c_slr))
print(sum(c_srr))
# Out:
# 5.451044063295041
# 5.377398629024087
#
# 4.614885381776328
# 4.567545973996796

# %%
sns.heatmap(np.reshape(A_rr[0], (21, 21)))
plt.show()
sns.heatmap(np.reshape(A_lr[0], (21, 21)))
plt.show()

# %%
plt.plot(np.transpose(D_rr)[0])
plt.show()
plt.plot(np.transpose(D_lr)[0])
plt.show()

# %% [markdown]
# ## Question 2.5

# %%
# tmp = np.linalg.svd(X,5)


U, sdiag, VH = np.linalg.svd(X,5)
S = np.zeros((m, n))
np.fill_diagonal(S, sdiag)
V = VH.T.conj()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-380-68faaabff0db> in <module>
#       2
#       3
# ----> 4 U, sdiag, VH = numpy.linalg.svd(X,5)
#       5 S = numpy.zeros((m, n))
#       6 numpy.fill_diagonal(S, sdiag)
#
# NameError: name 'numpy' is not defined

# %%
np.linalg.svd(X,5)[2].shape
# Out:
# (441, 441)

# %%
plt.plot(np.linalg.svd(TC,5)[1])

# %%
Z = np.linalg.svd(TC,5)[0]

# %%
plt.plot(TC[0])
plt.show()
plt.plot(Z[0])
plt.show()

# %%
def compute_Alr2(rho, X, D, Dt):
    step = 1/(np.linalg.norm(D @ Dt)*1.1)
    thr = rho*N*step
    Ao = np.zeros((nsrcs, 1))
    A = np.zeros((nsrcs, 1))
    A_lr = np.zeros((x1*x2, nsrcs))

    for k in range(0,x1*x2):
        tmp = step * (Dt @ (np.reshape(np.transpose(X)[k],(240,1)) - (D @ Ao)))
        A = Ao + tmp
        A = (1/(1+thr)) * np.sign(A)* np.maximum(np.zeros((nsrcs, 1)), abs(A)-thr) 
        for i in range(10):
            Ao = A
            A = Ao + step*(Dt @ (np.reshape(np.transpose(X)[k],(240,1)) - (D @ Ao)))
            A = (1/(1+thr)) * np.sign(A)*np.maximum(np.zeros((nsrcs, 1)), abs(A)-thr)
        A_lr[k] =  np.reshape(A, (6))

    A_lr = np.transpose(A_lr)
    return A_lr

# %%
U, sdiag, VH = np.linalg.svd(TC,5)
Z = np.zeros((6, 240))
np.fill_diagonal(Z, sdiag)

# %%
rho = 0.001
A_pcr = compute_Alr2(rho,X,np.transpose(Z),Z)
D_pcr = X @ np.transpose(A_pcr)
# Out:
# 0.0012410891234477814

# %%
sns.heatmap(np.reshape(A_pcr[0], (21, 21)))
plt.show()

# %%
plt.plot(np.transpose(D_pcr)[0])
plt.show()

# %%
A_pcr.shape
# Out:
# (6, 441)
